# %% [markdown]
# # Graficación

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
m = 2
b = 3
x = np.linspace(0, 10, 251)
y = m * x + b

# %%
plt.plot(x, y, c = "red", ls = "--", label = "$y_1$")
plt.plot(x, y + 2, c = "blue", ls = "-.", label = "$y_2$")
plt.xlabel("$x$")
plt.ylabel("$y(x)$")
plt.hlines(5, 0, 10, colors = "orange", label = "constant")
plt.legend(loc = "best")
plt.savefig("grafica1.pdf", bbox_inches = "tight")
plt.show()

# %%
plt.scatter(x, y, c = "red", s = 0.5, label = "$y_1$")
plt.scatter(x, y + 2, c = "blue", s = 0.5, label = "$y_2$")
plt.xlabel("$x$")
plt.ylabel("$y(x)$")
plt.hlines(5, 0, 10, colors = "orange", label = "constant")
plt.legend(loc = "best")
plt.show()

# %%
x = np.linspace(0, 100, 651)
y = np.random.normal(0, 10, 651)

# %%
plt.figure(figsize = (15, 3))
plt.scatter(x, y)
plt.show()

# %%
plt.hist(y, bins = 50)
# Out:
# (array([ 2.,  0.,  1.,  1.,  1.,  3.,  3.,  1.,  5.,  5., 11.,  6., 11.,
#         13., 16., 21., 11., 26., 33., 30., 24., 26., 35., 43., 30., 37.,
#         36., 29., 31., 37., 21., 22., 20., 17.,  9.,  5.,  4.,  9.,  3.,
#          1.,  2.,  2.,  1.,  1.,  2.,  1.,  0.,  1.,  0.,  2.]),
#  array([-31.54816899, -30.23797116, -28.92777333, -27.6175755 ,
#         -26.30737767, -24.99717984, -23.68698201, -22.37678418,
#         -21.06658635, -19.75638853, -18.4461907 , -17.13599287,
#         -15.82579504, -14.51559721, -13.20539938, -11.89520155,
#         -10.58500372,  -9.27480589,  -7.96460806,  -6.65441023,
#          -5.3442124 ,  -4.03401457,  -2.72381674,  -1.41361891,
#          -0.10342108,   1.20677675,   2.51697458,   3.82717241,
#           5.13737024,   6.44756807,   7.7577659 ,   9.06796373,
#          10.37816156,  11.68835939,  12.99855722,  14.30875505,
#          15.61895288,  16.92915071,  18.23934854,  19.54954637,
# ...

# %%
# make data
X, Y = np.meshgrid(np.linspace(-3, 3, 16), np.linspace(-3, 3, 16))
Z = (1 - X/2 + X**5 + Y**3) * np.exp(-X**2 - Y**2)

# %%
# plot
fig, ax = plt.subplots()

heatmap = ax.imshow(Z)
plt.colorbar(heatmap)

plt.show()

# %%
# Load the example flights dataset and convert to long-form
flights_long = sns.load_dataset("flights")
flights_long
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights = (
    flights_long
    .pivot(index="month", columns="year", values="passengers")
)
flights
# Out:
# year   1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  1960
# month
# Jan     112   115   145   171   196   204   242   284   315   340   360   417
# Feb     118   126   150   180   196   188   233   277   301   318   342   391
# Mar     132   141   178   193   236   235   267   317   356   362   406   419
# Apr     129   135   163   181   235   227   269   313   348   348   396   461
# May     121   125   172   183   229   234   270   318   355   363   420   472
# Jun     135   149   178   218   243   264   315   374   422   435   472   535
# Jul     148   170   199   230   264   302   364   413   465   491   548   622
# Aug     148   170   199   242   272   293   347   405   467   505   559   606
# Sep     136   158   184   209   237   259   312   355   404   404   463   508
# Oct     119   133   162   191   211   229   274   306   347   359   407   461
# Nov     104   114   146   172   180   203   237   271   305   310   362   390
# ...

# %%
# Draw a heatmap with the numeric values in each cell
f, ax = plt.subplots(figsize=(9, 6))
sns.heatmap(flights, annot=False, fmt="d", linewidths=.5, ax=ax)
# Out:
# <Axes: xlabel='year', ylabel='month'>
